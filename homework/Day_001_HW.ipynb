# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

#plt.figure(figsize = (10,6))
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend()
plt.show()

# %%
def mean_square_error(real,predict):
    MSE = sum((real-predict) ** 2) / len(real)
    return MSE

mse = mean_square_error(y,y_hat)
print("The Mean Square error is %.3f" % (mse))
# Out:
# The Mean Square error is 273.128

# %%
1. Kaggle datasets : moneyball
    (1) 資料裡有上壘率(OBP), 長打率(SLG), 以及每年的季賽/季後賽結果等等數據，能分析哪項打擊數據會更影響球隊成績
    (2) 此份資料為baseball-reference.com上的資料收集而成,這是一個有詳盡數據的棒球數據網站
    (3) 資料型態為csv
    (4) 比較 OOTP,OSLG(對手的上壘率,長打率)與我方同樣數據比較對比賽結果的影響程度
# Out:
#   File "<ipython-input-1-6e0e71581dde>", line 1
#     1. Kaggle datasets : moneyball
#             ^
# SyntaxError: invalid syntax

# %%
2. 
    (1) 提升業績應分為 
            a.載長距離的顧客
            b.多載顧客
        兩種方式,但載長距離顧客會消耗時間成本
        我會先將目標放在如何多載顧客,爭取客流量.
        分析甚麼時間會有較多顧客叫車,並在高峰時段配置更多司機,可有效提升業績
    (2) 資料可從司機記錄而來.每個司機紀錄自己載到顧客的時間,把一整天以小時為單位切分為24個時段,記錄每天每個時段之載客次數
    (3) 將資料存入excel裡,匯出成為csv檔
    (4) 觀察載客數較多的時段裡,收入與其他階段相比是否有變多
